# %%
import pandas as pd
from datetime import date
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
new_file = pd.read_csv('TSLA.csv', parse_dates=['Date'])
new_file.set_index('Date', inplace=True)
new_file.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2017-05-22  312.799988  314.369995  306.799988  310.350006  310.350006
# 2017-05-23  310.459991  310.730011  303.480011  303.859985  303.859985
# 2017-05-24  306.510010  311.000000  305.399994  310.220001  310.220001
# 2017-05-25  311.019989  316.970001  307.809998  316.829987  316.829987
# 2017-05-26  317.279999  325.489990  316.309998  325.140015  325.140015
#
#              Volume
# Date
# 2017-05-22  4329200
# 2017-05-23  4318400
# 2017-05-24  5033300
# 2017-05-25  5014000
# 2017-05-26  7802200

# %%
new_file['Adj Close'].plot(figsize=(16,12))

# %%
max_close_price = new_file['Adj Close'].max()
idx_close_price = new_file['Adj Close'].idxmax()
idx_close_price
# Out:
# Timestamp('2017-06-14 00:00:00')

# %%
new_file['Adj Close'].plot(figsize=(16,12))
vertical_line = plt.axvline(date(2017,6,14), linewidth=1, color='r')
horizontal_line = plt.axhline(y=max_close_price, linewidth=1, color='r')

# %%
from datetime import date
import pandas_datareader.data as web
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-28-2222d23c3381> in <module>()
#       1 from datetime import date
# ----> 2 import pandas_datareader.data as web
#
# ModuleNotFoundError: No module named 'pandas_datareader'
